# %%
import pandas as pd

# %%
df=pd.read_csv("Credit_card.csv")

# %%
df.shape
# Out:
# (167, 10)

# %%
df.head(2)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8  Amount  Class
# 0  0.098698  149.62      0
# 1  0.085102    2.69      0

# %%
df.isnull().sum()
# Out:
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# Amount    0
# Class     0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
a=df

# %%
X=a.drop("Amount",axis=1)

# %%
y=a[["Amount"]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
l=LinearRegression()

# %%
l.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
value=l.predict(X_test)

# %%
value
# Out:
# array([[ 113.21711995],
#        [ 132.81303321],
#        [ 107.73439907],
#        [ 251.6846512 ],
#        [   6.06530745],
#        [ -19.83720729],
#        [   4.94399076],
#        [-103.34723521],
#        [ -56.98291641],
#        [ 201.22369672],
#        [ -74.00973147],
#        [ -38.45266729],
#        [ -12.52739479],
#        [ 558.25597043],
#        [ 105.45999082],
#        [-111.2276246 ],
#        [ 216.40954241],
#        [ -47.06881355],
#        [ 198.79396966],
#        [-129.21481215],
#        [  62.48088349],
#        [ -10.63006853],
#        [ 127.33022714],
#        [ 108.10425939],
#        [  69.35667656],
#        [  58.50571353],
#        [ -58.18453787],
#        [  20.71707372],
#        [ -85.78318931],
#        [  42.20079325],
#        [ -53.01431982],
#        [ 145.35040259],
#        [  82.76768122],
#        [ -70.69469478]])

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
mean_squared_error(y_test,value)
# Out:
# 10015.26889345328

# %%
r2_score(y_test,value)
# Out:
# 0.36012563461315517

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X_test,l.predict(X_test))
# Out:
# [<matplotlib.lines.Line2D at 0x23da75dfb20>,
#  <matplotlib.lines.Line2D at 0x23da75dfbe0>,
#  <matplotlib.lines.Line2D at 0x23da75dfc70>,
#  <matplotlib.lines.Line2D at 0x23da75dfd60>,
#  <matplotlib.lines.Line2D at 0x23da75dfe20>,
#  <matplotlib.lines.Line2D at 0x23da75dfee0>,
#  <matplotlib.lines.Line2D at 0x23da75dffa0>,
#  <matplotlib.lines.Line2D at 0x23da75ec0a0>,
#  <matplotlib.lines.Line2D at 0x23da75ec160>]
